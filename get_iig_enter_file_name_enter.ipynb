# %%
# import lib
import os
import shutil

# input file name
file = str(input("Enter file name with extension (csv or txt): "))
file_name = 'drugname/' + file
file_name_loading = 'drugname/' + 'loading_' + file

# create file loading
if os.path.exists(file_name_loading):
    os.remove(file_name_loading)
    pass
else:
    shutil.copy2(file_name, file_name_loading)
# Out:
# Enter file name with extension (csv or txt): drugname_with_number.txt
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3632/3883949728.py in <module>
#      10 # create file loading
#      11 if os.path.exists(file_name_loading):
# ---> 12     os.remove(file_name_loading)
#      13 #     pass
#      14 else:
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'drugname/loading_drugname_with_number.txt'

# %%
import re
s = "_u1_v1"
print(re.sub('\d', '%d', s))
# Out:
# _u%d_v%d

# %%
f = open(file_name_loading,'r')
drugs_name_file = f.readlines()
for drug_name_raw in drugs_name_file:
    drug = drug_name_raw.replace(' ','+').replace('\n','').replace('-', '+').replace('/','+').replace('.','')
    string = drug
    for i in string:
        if i.isdigit():
            string.replace(i, "+")
    print(string)

# %%
f = open(file_name_loading,'r')
drugs_name_file = f.readlines()
for drug_name_raw in drugs_name_file:
    drug = drug_name_raw.replace(' ','+').replace('\n','').replace('-', '+').replace('/','+').replace('.','')
    import string
    old_string = drug
    new_string = "".join([s if s not in string.digits else "+" for s in old_string ])
    drug = new_string.replace('++++++','').replace('+++++','')
    print(new_string_1)
# Out:
# Alyacen
# Alyacen
# Blisovi+Fe
# Blisovi+Fe
# Cyclafem
# Cyclafem
# Cyclafem
# Dasetta
# Dasetta
# dienogest+estradiol+valerate
# drospirenone+ethinyl+estradiol+levomefolate
# estetrol+drospirenone
# etynodiol+ethinyl+estradiol
# Hailey
# Junel
# Junel
# Junel+Fe
# Junel+Fe
# Larin
# Larin
# Larin+FE
# Larin+FE
# levonorgestrel+oral+ethinyl+estradiol
# levonorgestrel+oral+ethinylestradiol+ferrous+bisglycinate
# Loestrin
# Loestrin
# Loestrin+Fe
# Loestrin+Fe
# mestranol+norethindrone
# Microgestin
# Microgestin
# Microgestin+Fe
# Microgestin+Fe
# Necon
# NorethinE
# norethindrone+acetate+ethinyl+estradiol+ferrous+fumarate
# norethindrone+ethinyl+estradiol+ferrous+fumarate
# Nortrel
# Nortrel
# Nortrel
# Nylia
# Nylia
# Pirmella
# Pirmella
# Tarina+FE
# ethinyl+estradiol+levonorgestrel+transdermal
# norelgestromin+ethinyl+estradiol
# lactic+acid+citric+acid+potassium+bitartrate+vaginal
# bazedoxifene+conjugated+estrogens
# Alyacen
# Alyacen
# Blisovi+Fe
# Blisovi+Fe
# Cyclafem
# Cyclafem
# Cyclafem
# Dasetta
# Dasetta
# dienogest+estradiol+valerate
# drospirenone+ethinyl+estradiol+levomefolate
# elagolix+estradiol+norethindrone+acetate
# etonogestrel+ethinyl+estradiol
# etynodiol+ethinyl+estradiol
# Hailey
# Junel
# Junel
# Junel+Fe
# Junel+Fe
# Larin
# Larin
# Larin+FE
# Larin+FE
# levonorgestrel+oral+ethinyl+estradiol
# Loestrin
# Loestrin
# Loestrin+Fe
# Loestrin+Fe
# mestranol+norethindrone
# Microgestin
# Microgestin
# Microgestin+Fe
# Microgestin+Fe
# Necon
# NorethinE
# norethindrone+acetate+ethinyl+estradiol+ferrous+fumarate
# norethindrone+ethinyl+estradiol+ferrous+fumarate
# Nortrel
# Nortrel
# Nortrel
# Nylia
# Nylia
# Pirmella
# Pirmella
# relugolix+estradiol+norethindrone
# segesterone+ethinyl+estradiol
# Tarina+FE
# conjugated+estrogens+medroxyprogesterone
# drospirenone+estradiol
# estradiol+levonorgestrel
# estradiol+norgestimate
# estradiol+progesterone
# elagolix+estradiol+norethindrone+acetate
# bazedoxifene+conjugated+estrogens
# lactic+acid+citric+acid+potassium+bitartrate+vaginal

# %%
f = open(file_name_loading,'r')
drugs_name_file = f.readlines()
for drug_name_raw in drugs_name_file:
    drug = drug_name_raw.replace(' ','+').replace('\n','').replace('-', '+').replace('/','+').replace('.','')
    import re
    print(re.sub('\d','',drug))
    print(drug)
# Out:
# Alyacen++
# Alyacen+1+35
# Alyacen+++
# Alyacen+7+7+7
# Blisovi+Fe++
# Blisovi+Fe+15+30
# Blisovi+Fe++
# Blisovi+Fe+1+20
# Cyclafem++
# Cyclafem+05+35
# Cyclafem++
# Cyclafem+1+35
# Cyclafem+++
# Cyclafem+7+7+7
# Dasetta++
# Dasetta+1+35
# Dasetta+++
# Dasetta+7+7+7
# dienogest+estradiol+valerate
# dienogest+estradiol+valerate
# drospirenone+ethinyl+estradiol+levomefolate
# drospirenone+ethinyl+estradiol+levomefolate
# estetrol+drospirenone
# estetrol+drospirenone
# etynodiol+ethinyl+estradiol
# etynodiol+ethinyl+estradiol
# Hailey++
# Hailey+15+30
# Junel++
# Junel+15+30
# Junel++
# Junel+1+20
# Junel+Fe++
# Junel+Fe+15+30
# Junel+Fe++
# Junel+Fe+1+20
# Larin++
# Larin+15+30
# Larin++
# Larin+1+20
# Larin+FE++
# Larin+FE+15+30
# Larin+FE++
# Larin+FE+1+20
# levonorgestrel+oral+ethinyl+estradiol
# levonorgestrel+oral+ethinyl+estradiol
# levonorgestrel+oral+ethinylestradiol+ferrous+bisglycinate
# levonorgestrel+oral+ethinylestradiol+ferrous+bisglycinate
# Loestrin++
# Loestrin+15+30
# Loestrin++
# Loestrin+1+20
# Loestrin+Fe++
# Loestrin+Fe+15+30
# Loestrin+Fe++
# Loestrin+Fe+1+20
# mestranol+norethindrone
# mestranol+norethindrone
# Microgestin++
# Microgestin+15+30
# Microgestin++
# Microgestin+1+20
# Microgestin+Fe++
# Microgestin+Fe+15+30
# Microgestin+Fe++
# Microgestin+Fe+1+20
# Necon++
# Necon+05+35
# Norethin++E
# Norethin+1+35E
# norethindrone+acetate+ethinyl+estradiol+ferrous+fumarate
# norethindrone+acetate+ethinyl+estradiol+ferrous+fumarate
# norethindrone+ethinyl+estradiol+ferrous+fumarate
# norethindrone+ethinyl+estradiol+ferrous+fumarate
# Nortrel++
# Nortrel+05+35
# Nortrel++
# Nortrel+1+35
# Nortrel+++
# Nortrel+7+7+7
# Nylia++
# Nylia+1+35
# Nylia+++
# Nylia+7+7+7
# Pirmella++
# Pirmella+1+35
# Pirmella+++
# Pirmella+7+7+7
# Tarina+FE++
# Tarina+FE+1+20
# ethinyl+estradiol+levonorgestrel+transdermal
# ethinyl+estradiol+levonorgestrel+transdermal
# norelgestromin+ethinyl+estradiol
# norelgestromin+ethinyl+estradiol
# lactic+acid+citric+acid+potassium+bitartrate+vaginal
# lactic+acid+citric+acid+potassium+bitartrate+vaginal
# bazedoxifene+conjugated+estrogens
# bazedoxifene+conjugated+estrogens
# Alyacen++
# Alyacen+1+35
# Alyacen+++
# Alyacen+7+7+7
# Blisovi+Fe++
# Blisovi+Fe+15+30
# Blisovi+Fe++
# Blisovi+Fe+1+20
# Cyclafem++
# Cyclafem+05+35
# Cyclafem++
# Cyclafem+1+35
# Cyclafem+++
# Cyclafem+7+7+7
# Dasetta++
# Dasetta+1+35
# Dasetta+++
# Dasetta+7+7+7
# dienogest+estradiol+valerate
# dienogest+estradiol+valerate
# drospirenone+ethinyl+estradiol+levomefolate
# drospirenone+ethinyl+estradiol+levomefolate
# elagolix+estradiol+norethindrone+acetate
# elagolix+estradiol+norethindrone+acetate
# etonogestrel+ethinyl+estradiol
# etonogestrel+ethinyl+estradiol
# etynodiol+ethinyl+estradiol
# etynodiol+ethinyl+estradiol
# Hailey++
# Hailey+15+30
# Junel++
# Junel+15+30
# Junel++
# Junel+1+20
# Junel+Fe++
# Junel+Fe+15+30
# Junel+Fe++
# Junel+Fe+1+20
# Larin++
# Larin+15+30
# Larin++
# Larin+1+20
# Larin+FE++
# Larin+FE+15+30
# Larin+FE++
# Larin+FE+1+20
# levonorgestrel+oral+ethinyl+estradiol
# levonorgestrel+oral+ethinyl+estradiol
# Loestrin++
# Loestrin+15+30
# Loestrin++
# Loestrin+1+20
# Loestrin+Fe++
# Loestrin+Fe+15+30
# Loestrin+Fe++
# Loestrin+Fe+1+20
# mestranol+norethindrone
# mestranol+norethindrone
# Microgestin++
# Microgestin+15+30
# Microgestin++
# Microgestin+1+20
# Microgestin+Fe++
# Microgestin+Fe+15+30
# Microgestin+Fe++
# Microgestin+Fe+1+20
# Necon++
# Necon+05+35
# Norethin++E
# Norethin+1+35E
# norethindrone+acetate+ethinyl+estradiol+ferrous+fumarate
# norethindrone+acetate+ethinyl+estradiol+ferrous+fumarate
# norethindrone+ethinyl+estradiol+ferrous+fumarate
# norethindrone+ethinyl+estradiol+ferrous+fumarate
# Nortrel++
# Nortrel+05+35
# Nortrel++
# Nortrel+1+35
# Nortrel+++
# Nortrel+7+7+7
# Nylia++
# Nylia+1+35
# Nylia+++
# Nylia+7+7+7
# Pirmella++
# Pirmella+1+35
# Pirmella+++
# Pirmella+7+7+7
# relugolix+estradiol+norethindrone
# relugolix+estradiol+norethindrone
# segesterone+ethinyl+estradiol
# segesterone+ethinyl+estradiol
# Tarina+FE++
# Tarina+FE+1+20
# conjugated+estrogens+medroxyprogesterone
# conjugated+estrogens+medroxyprogesterone
# drospirenone+estradiol
# drospirenone+estradiol
# estradiol+levonorgestrel
# estradiol+levonorgestrel
# estradiol+norgestimate
# estradiol+norgestimate
# estradiol+progesterone
# estradiol+progesterone
# elagolix+estradiol+norethindrone+acetate
# elagolix+estradiol+norethindrone+acetate
# bazedoxifene+conjugated+estrogens
# bazedoxifene+conjugated+estrogens
# lactic+acid+citric+acid+potassium+bitartrate+vaginal
# lactic+acid+citric+acid+potassium+bitartrate+vaginal

# %%
# remove iig exist
f = open(file_name_loading,'r')
drugs_name_file = f.readlines()
for drug_name_raw in drugs_name_file:
    drug = drug_name_raw.replace(' ','+').replace('\n','').replace('-', '+').replace('/','+').replace('.','')
    from pathlib import Path
    drug_iig_name = drug + '_inactive_ingredient_list.txt'
    path = 'iigdata/'
    filepath = path + drug_iig_name
    if os.path.isfile(filepath):
        with open(file_name_loading, "r+") as f:
            d = f.readlines()
            f.seek(0)
            for i in d:
                if i != drug_name_raw:
                    f.write(i)
            f.truncate()
    else:
        pass

# %%
# Remove drug name len < 3 (not key name)
f = open(file_name_loading,'r')
drugs_name_file = f.readlines()
for drug_name_raw in drugs_name_file:
    drug = drug_name_raw.replace(' ','+').replace('\n','').replace('-', '+')
    if len(drug) <3:
        with open(file_name_loading, "r+") as f:
            d = f.readlines()
            f.seek(0)
            for i in d:
                if i != drug_name_raw:
                    f.write(i)
            f.truncate()
    else:
        pass
 
# run ok
# remove drug name if number
f = open(file_name_loading,'r')
drugs_name_file = f.readlines()
for drug_name_raw in drugs_name_file:
    drug = drug_name_raw.replace(' ','+').replace('\n','').replace('-', '+')
    if drug.isdigit():
        with open(file_name_loading, "r+") as f:
            d = f.readlines()
            f.seek(0)
            for i in d:
                if i != drug_name_raw:
                    f.write(i)
            f.truncate()
    else:
        pass
        
        
# run ok
# get iig and remove line

f = open(file_name_loading,'r')
drugs_name_file = f.readlines()
for drug_name_raw in drugs_name_file:
    drug = drug_name_raw.replace(' ','+').replace('\n','').replace('-', '+')
    # get inactive ingredient
    import src.pharmappiig013 as pa
    try:
        print(f'{drug} loading!')
        pa.get_inactive_ingredient(name_drug=drug)
        print(f'{drug} done!')
        print("+---------------------------+---------------------------+")
    except:
        print(f'{drug} no found in DailyMed or run error!')
        print("+---------------------------+---------------------------+")
    with open(file_name_loading, "r+") as f:
        d = f.readlines()
        f.seek(0)
        for i in d:
            if i != drug_name_raw:
                f.write(i)
        f.truncate()
